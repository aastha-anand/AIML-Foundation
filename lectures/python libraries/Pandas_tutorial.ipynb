# %%
# !pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/11.0 MB 1.8 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.3/11.0 MB 2.1 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.6/11.0 MB 2.1 MB/s eta 0:00:05
#    ------- -------------------------------- 2.1/11.0 MB 2.1 MB/s eta 0:00:05
#    --------- ------------------------------ 2.6/11.0 MB 2.1 MB/s eta 0:00:04
#    ----------- ---------------------------- 3.1/11.0 MB 2.2 MB/s eta 0:00:04
#    ------------- -------------------------- 3.7/11.0 MB 2.2 MB/s eta 0:00:04
#    --------------- ------------------------ 4.2/11.0 MB 2.2 MB/s eta 0:00:04
#    --------------- ------------------------ 4.2/11.0 MB 2.2 MB/s eta 0:00:04
#    ------------------ --------------------- 5.0/11.0 MB 2.1 MB/s eta 0:00:03
# ...

# %%
import pandas as pd

# %%
#dataframe
info={
    "Name":["Jonh","Query","Ram"],
    "CGPA":[8.9,9.0,9.3]
}
df=pd.DataFrame(info)
print(df)
# Out:
#     Name  CGPA
# 0   Jonh   8.9
# 1  Query   9.0
# 2    Ram   9.3

# %%
df
# Out:
#     Name  CGPA
# 0   Jonh   8.9
# 1  Query   9.0
# 2    Ram   9.3

# %%
#series
s=pd.Series([1,2,3,4,5])
print(s)
print(type(s))

#index
print(s[0])
print(s[2])

# %%
s=pd.Series([10,40,30,80,25],index=["A","B","C","D","E"])
print(s)
print(s["A"])
# Out:
# A    10
# B    40
# C    30
# D    80
# E    25
# dtype: int64

# %%
s1=pd.Series([1,2,3,4,5])
s2=pd.Series([10,20,30,40,50])

print(s1+s2)
s1[0]=100
print(f"s1:\n{s1}")
s1=s1.drop(1)
##changes_s1=s1.drop(0)
print(f"s1:\n{s1}")
#print(f"s2: \n{changes_s1}")
# Out:
# 0    11
# 1    22
# 2    33
# 3    44
# 4    55
# dtype: int64
# s1:
# 0    100
# 1      2
# 2      3
# 3      4
# 4      5
# dtype: int64
# s1:
# 0    100
# 2      3
# 3      4
# 4      5
# dtype: int64
